# %% [markdown]
# from azure.storage.blob import BlobServiceClient
#
# # Connect to Blob Storage
# connection_string = "your_connection_string"
# container_name = "your_container"
# blob_name = "your_file.xlsx"
#
# # Download the file locally first
# blob_service_client = BlobServiceClient.from_connection_string(connection_string)
# blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
#
# with open("temp_file.xlsx", "wb") as download_file:
#     download_file.write(blob_client.download_blob().readall())
#
# # Now read with pandas
# df = pd.read_excel("temp_file.xlsx")

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('RW_ACTUALS_ALL_Processed_PRF.csv')

df
# Out:
#        CASENO COUNTRY_SHORT  \
# 0       52502            DE
# 1       47726            NL
# 2       48776            NO
# 3       49329            UK
# 4       47405            UK
# ...       ...           ...
# 21015   36124            DE
# 21016   39175            UK
# 21017   44084            DE
# 21018   51156            DE
# 21019   52477            NO
#
#                                                    TITLE         CASE_TYPE  \
# 0                          Kohlestaub-Leckage Brenner 42       Environment
# 1                                Grachtwater Temperatuur       Environment
# 2      Utsläpp av kylvatten från det interna kylvatte...       Environment
# 3                          CW Discharge Pipework Failure       Environment
# 4      Main Cooling Water - Pipe failure - Loss of co...       Environment
# ...                                                  ...               ...
# 21015    Stromkabel Beleuchtung nicht mehr ordnungsgemäß            Safety
# ...

# %%
df1 = pd.read_csv('Default of credit card clients.csv')

# %%
df1
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...
